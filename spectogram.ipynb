# %% [markdown]
# <a href="https://colab.research.google.com/github/Wolfman1219/Signallar_ustida/blob/main/spectogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np

# %%
dat = sio.loadmat(r"/content/drive/MyDrive/dataset_uchun/Data.mat")
data1 = np.resize(dat['data1'], 2000)
data2 = np.resize(dat['data2'], 2000)
data3 = np.resize(dat['data3'], 2000)

# %%
# plt.subplot(221)
powerSpectrum, freqenciesFound, time, imageAxis = plt.specgram(data1, Fs=2000)
plt.show()
# plt.subplot(222)
# plt.plot(powerSpectrum)
# print(freqenciesFound) cv2

rasm = cv2.imread('/content/drive/MyDrive/man in green background.jpg')
rasm = cv2.cvtColor(rasm, cv2.COLOR_BGR2RGB)
plt.imshow(rasm)
# print(time)
# print(imageAxis)
